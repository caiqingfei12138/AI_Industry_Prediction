# %%
import pandas as pd
import numpy as np

data = pd.read_excel( 'H:\\java\\python\\src\\machinelearning\\seconddata\\raw_data\\训练_20180117.xlsx')
tool_cols = ['TOOL' , 'Tool', 'TOOL_ID','Tool (#1)','TOOL (#1)','TOOL (#2)',
                 'Tool (#2)','Tool (#3)','Tool (#4)','OPERATION_ID','Tool (#5)','TOOL (#3)']
tool  = data[tool_cols]
# Out:
#     TOOL Tool TOOL_ID Tool (#1) TOOL (#1) TOOL (#2) Tool (#2) Tool (#3)  \
# 0      O    B       N         E         V         B         V         R
# 1      O    B       N         E         V         B         V         R
# 2      O    B       N         E         V         B         V         R
# 3      O    B       N         E         V         B         V         R
# 4      N    B       E         E         V         B         V         R
# 5      L    B       E         E         V         B         V         R
# 6      N    A       E         E         T         C         V         R
# 7      O    A       E         E         T         C         V         R
# 8      L    A       E         E         T         C         V         R
# 9      O    A       E         E         T         C         V         R
# 10     N    A       E         E         T         C         V         R
# 11     O    A       E         E         T         C         V         R
# ...

# %%
IsDuplicated=tool.duplicated()

# %%
IsDuplicated.to_csv( 'H:\\java\\python\\src\\machinelearning\\seconddata\\expandelements\\')
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775     True
# 776     True
# 777     True
# 778    False
# 779     True
# 780     True
# 781     True
# 782     True
# 783     True
# 784     True
# 785     True
# 786     True
# 787    False
# 788     True
# 789     True
# 790     True
# 791    False
# 792    False
# 793     True
# 794    False
# 795    False
# 796     True
# 797     True
# 798     True
# 799     True
# Length: 800, dtype: bool

# %%
tool[IsDuplicated]
# Out:
#     TOOL Tool TOOL_ID Tool (#1) TOOL (#1) TOOL (#2) Tool (#2) Tool (#3)  \
# 1      O    B       N         E         V         B         V         R
# 2      O    B       N         E         V         B         V         R
# 3      O    B       N         E         V         B         V         R
# 9      O    A       E         E         T         C         V         R
# 10     N    A       E         E         T         C         V         R
# 11     O    A       E         E         T         C         V         R
# 12     N    A       E         E         T         C         V         R
# 13     O    A       E         E         T         C         V         R
# 16     L    B       E         E         K         B         V         Q
# 17     M    B       E         E         K         B         V         Q
# 18     L    B       E         E         K         B         V         Q
# 19     M    B       E         E         K         B         V         Q
# ...
